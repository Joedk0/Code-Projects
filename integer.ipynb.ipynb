# %%
n = int(input()) #creamos una variable que contenga un input que el usuario va a poner

#aca se coloca el numero que el usuario puso en el input

if (n % 2 == 1 ):# si el numero divido por dos deja sobra es un numero inpar, si no deja sobra es par ya que se dividen y no deja numeros sobrantes
# en este caso ponemos ==1 ya que si el numero divido es igual a 1 numero cualquiera quiere decir que es inpar
    print("Weird")
else:
  if (n >= 2 and n <= 5):
      print("not weird")
  elif (n >= 6 and n<=20):
      print("Weird")
  elif (n > 20 ):
    print ("Not Weird")
# Out:
# 20
# weird
